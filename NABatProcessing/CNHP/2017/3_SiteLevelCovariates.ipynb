# %% [markdown]
# ### This is title

# %%
from pathlib import Path

import  pandas as pd
import numpy as np
# import ulmo

# %%
output_dname = r"Z:\TSH\DD274_NABat\CNHP_data_processing\Derived\2017_output"
out_dir = Path(output_dname)

# %%
site_md_fname = r"F:\CO_NABat\CO NABAT 2017 Bulk_Stationary_Acoustic_Template.csv"
site_md = pd.read_csv(site_md_fname, skiprows=[1], parse_dates=['First Monitoring Night', 'Fourth Monitoring Night'])
site_md = site_md.rename({'Grts Id':'GridCellID', 'Location Name':'SiteID'}, axis=1)

site_md = site_md.set_index(['GridCellID', 'SiteID'], drop=False)

from pyproj import Proj, transform

inProj = Proj(init='epsg:26913')
outProj = Proj(init='epsg:4326')

def utm_to_wgs84(row):    
    x1,y1 = row['UTME'], row['UTMN']
    x2,y2 = transform(inProj,outProj,x1,y1)
    return (x2,y2)

site_md['Long'], site_md['Lat'] = zip(*site_md.apply(utm_to_wgs84, axis=1))


site_md.head()
# Out:
#                    GridCellID SiteID    UTME     UTMN First Monitoring Night  \
# GridCellID SiteID
# 2          NW               2     NW  170440  4355996             2017-06-28
#            SW               2     SW  174304  4354564             2017-06-28
#            NE               2     NE  176892  4360344             2017-06-28
#            SE               2     SE  178373  4353544             2017-06-28
# 61         NE              61     NE  548408  4211808             2017-06-21
#
#                   Fourth Monitoring Night                      Detector  \
# GridCellID SiteID
# 2          NW                  2017-07-01    WILDLIFE ACOUSTICS SM2Bat+
#            SW                  2017-07-01    WILDLIFE ACOUSTICS SM2Bat+
#            NE                  2017-07-01    WILDLIFE ACOUSTICS SM2Bat+
#            SE                  2017-07-01    WILDLIFE ACOUSTICS SM2Bat+
# 61         NE                  2017-06-24  WILDLIFE ACOUSTICS SM2Bat192
#
#                                   Microphone  Microphone Orientation  \
# GridCellID SiteID
# 2          NW      Wildlife Acoustics SMX-US                     NaN
#            SW      Wildlife Acoustics SMX-US                     NaN
#            NE      Wildlife Acoustics SMX-US                     NaN
#            SE      Wildlife Acoustics SMX-US                     NaN
# 61         NE      Wildlife Acoustics SMX-US                     NaN
#
#                    Microphone Height (meters)  \
# GridCellID SiteID
# 2          NW                             2.0
#            SW                             2.0
#            NE                             2.0
#            SE                             2.0
# 61         NE                             3.0
#
#                    Distance to Nearest Clutter (meters) Clutter Type  \
# GridCellID SiteID
# 2          NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 61         NE                                       NaN   vegetation
#
#                    Distance to Nearest Water (meters)  Water Type  \
# GridCellID SiteID
# 2          NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 61         NE                                     NaN         NaN
#
#                    Percent Clutter Broad Habitat Type  \
# GridCellID SiteID
# 2          NW                  NaN          shrubland
#            SW                  NaN          shrubland
#            NE                  NaN          shrubland
#            SE                  NaN          shrubland
# 61         NE                  NaN            prairie
#
#                   Audio Recording Name (*.wav *.zc) Software Type        Long  \
# GridCellID SiteID
# 2          NW                                    FS   Sonobat 4.x -108.821023
#            SW                                    FS   Sonobat 4.x -108.775622
#            NE                                    FS   Sonobat 4.x -108.748456
#            SE                                    FS   Sonobat 4.x -108.728060
# 61         NE                                    FS   Sonobat 4.x -104.448246
#
#                          Lat
# GridCellID SiteID
# 2          NW      39.290652
#            SW      39.279238
#            NE      39.332177
#            SE      39.271585
# 61         NE      38.052719

# %%
table4 = site_md[['GridCellID', 'SiteID', 'Lat', 'Long', 'Detector', 'Microphone', 'Microphone Orientation', 
                 'Microphone Height (meters)', 'Distance to Nearest Clutter (meters)', 'Clutter Type',  
                 'Distance to Nearest Water (meters)', 'Water Type', 'Percent Clutter',
                 'Broad Habitat Type', 'Audio Recording Name (*.wav *.zc)', 'Software Type']]

table4.head()
# Out:
#                    GridCellID SiteID        Lat        Long  \
# GridCellID SiteID
# 2          NW               2     NW  39.290652 -108.821023
#            SW               2     SW  39.279238 -108.775622
#            NE               2     NE  39.332177 -108.748456
#            SE               2     SE  39.271585 -108.728060
# 61         NE              61     NE  38.052719 -104.448246
#
#                                        Detector                 Microphone  \
# GridCellID SiteID
# 2          NW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            NE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
# 61         NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#
#                    Microphone Orientation  Microphone Height (meters)  \
# GridCellID SiteID
# 2          NW                         NaN                         2.0
#            SW                         NaN                         2.0
#            NE                         NaN                         2.0
#            SE                         NaN                         2.0
# 61         NE                         NaN                         3.0
#
#                    Distance to Nearest Clutter (meters) Clutter Type  \
# GridCellID SiteID
# 2          NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 61         NE                                       NaN   vegetation
#
#                    Distance to Nearest Water (meters)  Water Type  \
# GridCellID SiteID
# 2          NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 61         NE                                     NaN         NaN
#
#                    Percent Clutter Broad Habitat Type  \
# GridCellID SiteID
# 2          NW                  NaN          shrubland
#            SW                  NaN          shrubland
#            NE                  NaN          shrubland
#            SE                  NaN          shrubland
# 61         NE                  NaN            prairie
#
#                   Audio Recording Name (*.wav *.zc) Software Type
# GridCellID SiteID
# 2          NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 61         NE                                    FS   Sonobat 4.x

# %% [markdown]
# ### Let's add some site specific attributes to each of these

# %%
import matplotlib.pyplot as plt
import scipy.ndimage as ndi

import rasterio
import rasterstats
from owslib.wcs import WebCoverageService

# %%
def calc_tpi(data, size=10):
    max_data = ndi.maximum_filter(data, size=size)
    min_data = ndi.minimum_filter(data, size=size)
    mean_data = ndi.uniform_filter(data, size=size)

    tpi = (mean_data-min_data)/(max_data-min_data)
    return tpi

# %%
def calc_tri(data, size=3):
    max_data = ndi.maximum_filter(data, size=size)
    min_data = ndi.minimum_filter(data, size=size)

    tri = np.sqrt(np.absolute((np.square(max_data) - np.square(min_data) )))
    return tri

# %%
wcs=WebCoverageService('https://elevation.nationalmap.gov:443/arcgis/services/3DEPElevation/ImageServer/WCSServer',version='1.0.0')

# this is the resolution for 1 arc second (30m DEM)
res = 0.00027777777803598/3

elev=wcs['DEP3ElevationPrototype']


def get_site_elev(row):
    
    lat, long = row['Lat'], row['Long']
    bounds = (long-(10*res)-res/2,  lat-(10*res)-res/2, long+(10*res)+res/2,  lat+(10*res)+res/2)

    
    output = wcs.getCoverage(identifier='DEP3ElevationPrototype', bbox=bounds,
                             format='GeoTIFF', resx=res, resy=res, crs=4326)
    contents = output.read()

    import rasterio
    from rasterio.io import MemoryFile
    elev = MemoryFile(contents).open()
    data = elev.read().squeeze()
    
    point_elevation = data[10, 10]
    point_tpi = calc_tpi(data)[10, 10]
    point_tri = calc_tri(data)[10, 10]
    
    return (point_elevation, point_tpi, point_tri)

get_site_elev(table4.iloc[0])
# Out:
# (1449.9078, 0.60479105, 120.18943)

# %%
table4['elevation'], table4['tpi'], table4['tri'] = zip(*table4.apply(get_site_elev, axis=1))
# Out:
# C:\Anaconda3\envs\pyviz\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Anaconda3\envs\pyviz\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
table4
# Out:
#                    GridCellID SiteID        Lat        Long  \
# GridCellID SiteID
# 2          NW               2     NW  39.290652 -108.821023
#            SW               2     SW  39.279238 -108.775622
#            NE               2     NE  39.332177 -108.748456
#            SE               2     SE  39.271585 -108.728060
# 61         NE              61     NE  38.052719 -104.448246
#            NW              61     NW  38.061467 -104.512655
#            SE              61     SE  38.014977 -104.460525
#            SW              61     SW  38.008945 -104.524736
# 82         NE              82     NE  40.620777 -102.642855
#            SE              82     SE  40.533334 -102.633351
# 157        NE             157     NE  37.860529 -108.435896
#            NW             157     NW  37.885345 -108.465491
#            SE             157     SE  37.862235 -108.353384
#            SW             157     SW  37.860700 -108.435893
# 221        E              221      E  37.556925 -108.996175
#            NE             221     NE  37.585943 -108.998736
#            NE2            221    NE2  37.577465 -109.003284
# 253        NW             253     NW  40.421876 -103.952328
#            SW             253     SW  40.379807 -103.956561
# 306        NE             306     NE  38.221214 -102.168790
#            SE             306     SE  38.152382 -102.150757
# 317        NE             317     NE  38.785086 -104.804083
#            NW             317     NW  38.742067 -104.829182
#            SE             317     SE  38.723400 -104.809095
#            SW             317     SW  38.731110 -104.818117
# 338        SE             338     SE  40.939646 -103.403666
#            SW             338     SW  40.964201 -103.466009
# 381        NE             381     NE  37.682709 -104.747103
#            SE             381     SE  37.646588 -104.757961
#            SW             381     SW  37.656018 -104.837494
# ...                       ...    ...        ...         ...
# 2749       SE            2749     SE  40.023877 -105.392171
#            NE            2749     NE  40.070610 -105.425475
#            NW            2749     NW  40.068752 -105.456856
# 2781       SE            2781     SE  37.739554 -107.076793
#            NW            2781     NW  37.780543 -107.175427
# 2834       SW            2834     SW  40.304854 -103.623445
#            SE            2834     SE  40.335595 -103.546394
#            NE            2834     NE  40.372281 -103.543003
# 2877       NW            2877     NW  37.923726 -106.230370
#            SW            2877     SW  37.897670 -106.235611
#            NE            2877     NE  37.927387 -106.196114
# 2941       NW            2941     NW  40.923614 -106.920920
#            SW            2941     SW  40.894744 -106.908498
#            NE            2941     NE  40.915528 -106.872594
#            SE            2941     SE  40.885405 -106.869312
# 3005       SW            3005     SW  40.296933 -105.051960
#            SE            3005     SE  40.309518 -104.970567
#            NE            3005     NE  40.385202 -104.960402
#            NW            3005     NW  40.382898 -105.031998
# 3053       SW            3053     SW  37.019837 -105.919396
#            NE            3053     NE  37.058908 -105.820430
#            SE            3053     SE  37.047911 -105.819165
# 3069       NE            3069     NE  40.430000 -108.465995
#            SE            3069     SE  40.397002 -108.453003
#            NW            3069     NW  40.419004 -108.510999
#            SW            3069     SW  40.364004 -108.490997
# 3197       SE            3197     SE  37.838292 -103.419673
#            NE            3197     NE  37.867058 -103.417558
# 3229       NW            3229     NW  38.666003 -107.891999
#            SW            3229     SW  38.649004 -107.888994
#
#                                        Detector                 Microphone  \
# GridCellID SiteID
# 2          NW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            NE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
# 61         NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
# 82         NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 157        NE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            NW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
# 221        E       WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NE2     WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
# 253        NW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 306        NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 317        NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 338        SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 381        NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-U1
# ...                                         ...                        ...
# 2749       SE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-U1
#            NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-U1
#            NW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-U1
# 2781       SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 2834       SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 2877       NW         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#            SW         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#            NE         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
# 2941       NW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 3005       SW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-U1
# 3053       SW         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#            NE         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#            SE         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
# 3069       NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SW      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 3197       SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
# 3229       NW         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#            SW         WILDLIFE ACOUSTICS SM3Bat  Wildlife Acoustics SMM-U1
#
#                    Microphone Orientation  Microphone Height (meters)  \
# GridCellID SiteID
# 2          NW                         NaN                         2.0
#            SW                         NaN                         2.0
#            NE                         NaN                         2.0
#            SE                         NaN                         2.0
# 61         NE                         NaN                         3.0
#            NW                         NaN                         3.0
#            SE                         NaN                         3.0
#            SW                         NaN                         3.0
# 82         NE                         NaN                         2.4
#            SE                         NaN                         2.4
# 157        NE                         NaN                         2.5
#            NW                         NaN                         2.5
#            SE                         NaN                         2.5
#            SW                         NaN                         2.5
# 221        E                          NaN                         8.0
#            NE                         NaN                         6.0
#            NE2                        NaN                         8.0
# 253        NW                         NaN                         2.4
#            SW                         NaN                         2.4
# 306        NE                         NaN                         3.0
#            SE                         NaN                         3.0
# 317        NE                         NaN                         3.0
#            NW                         NaN                         3.0
#            SE                         NaN                         3.0
#            SW                         NaN                         3.0
# 338        SE                         NaN                         2.4
#            SW                         NaN                         2.4
# 381        NE                         NaN                         2.4
#            SE                         NaN                         2.4
#            SW                         NaN                         2.4
# ...                                   ...                         ...
# 2749       SE                         NaN                         2.4
#            NE                         NaN                         2.4
#            NW                         NaN                         2.4
# 2781       SE                         NaN                         2.0
#            NW                         NaN                         2.0
# 2834       SW                         NaN                         2.4
#            SE                         NaN                         2.4
#            NE                         NaN                         2.4
# 2877       NW                         NaN                         2.0
#            SW                         NaN                         2.0
#            NE                         NaN                         2.0
# 2941       NW                         NaN                         2.1
#            SW                         NaN                         2.1
#            NE                         NaN                         2.1
#            SE                         NaN                         1.5
# 3005       SW                         NaN                         2.4
#            SE                         NaN                         2.4
#            NE                         NaN                         2.4
#            NW                         NaN                         2.4
# 3053       SW                         NaN                         2.0
#            NE                         NaN                         2.0
#            SE                         NaN                         2.0
# 3069       NE                         NaN                         2.0
#            SE                         NaN                         2.0
#            NW                         NaN                         2.0
#            SW                         NaN                         2.0
# 3197       SE                         NaN                         3.0
#            NE                         NaN                         3.0
# 3229       NW                         NaN                         2.0
#            SW                         NaN                         2.0
#
#                    Distance to Nearest Clutter (meters) Clutter Type  \
# GridCellID SiteID
# 2          NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 61         NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 82         NE                                       NaN        water
#            SE                                       NaN   vegetation
# 157        NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 221        E                                        NaN   vegetation
#            NE                                       NaN   vegetation
#            NE2                                      NaN   vegetation
# 253        NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 306        NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 317        NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 338        SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 381        NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# ...                                                 ...          ...
# 2749       SE                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
# 2781       SE                                       NaN   vegetation
#            NW                                       NaN   vegetation
# 2834       SW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            NE                                       NaN   vegetation
# 2877       NW                                       NaN         rock
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
# 2941       NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 3005       SW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
# 3053       SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 3069       NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 3197       SE                                       NaN   vegetation
#            NE                                       NaN   vegetation
# 3229       NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#
#                    Distance to Nearest Water (meters)  Water Type  \
# GridCellID SiteID
# 2          NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 61         NE                                     NaN         NaN
#            NW                                     NaN         NaN
#            SE                                     NaN         NaN
#            SW                                     NaN         NaN
# 82         NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 157        NE                                     NaN         NaN
#            NW                                     NaN         NaN
#            SE                                     NaN         NaN
#            SW                                     NaN         NaN
# 221        E                                      NaN         NaN
#            NE                                     NaN         NaN
#            NE2                                    NaN         NaN
# 253        NW                                     NaN         NaN
#            SW                                     NaN         NaN
# 306        NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 317        NE                                     NaN         NaN
#            NW                                     NaN         NaN
#            SE                                     NaN         NaN
#            SW                                     NaN         NaN
# 338        SE                                     NaN         NaN
#            SW                                     NaN         NaN
# 381        NE                                     NaN         NaN
#            SE                                     NaN         NaN
#            SW                                     NaN         NaN
# ...                                               ...         ...
# 2749       SE                                     NaN         NaN
#            NE                                     NaN         NaN
#            NW                                     NaN         NaN
# 2781       SE                                     NaN         NaN
#            NW                                     NaN         NaN
# 2834       SW                                     NaN         NaN
#            SE                                     NaN         NaN
#            NE                                     NaN         NaN
# 2877       NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
# 2941       NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 3005       SW                                     NaN         NaN
#            SE                                     NaN         NaN
#            NE                                     NaN         NaN
#            NW                                     NaN         NaN
# 3053       SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 3069       NE                                     NaN         NaN
#            SE                                     NaN         NaN
#            NW                                     NaN         NaN
#            SW                                     NaN         NaN
# 3197       SE                                     NaN         NaN
#            NE                                     NaN         NaN
# 3229       NW                                     NaN         NaN
#            SW                                     NaN         NaN
#
#                    Percent Clutter Broad Habitat Type  \
# GridCellID SiteID
# 2          NW                  NaN          shrubland
#            SW                  NaN          shrubland
#            NE                  NaN          shrubland
#            SE                  NaN          shrubland
# 61         NE                  NaN            prairie
#            NW                  NaN            prairie
#            SE                  NaN            prairie
#            SW                  NaN            prairie
# 82         NE                  NaN        agriculture
#            SE                  NaN        agriculture
# 157        NE                  NaN   forest-deciduous
#            NW                  NaN          shrubland
#            SE                  NaN     forest-conifer
#            SW                  NaN          shrubland
# 221        E                   NaN          shrubland
#            NE                  NaN          shrubland
#            NE2                 NaN          shrubland
# 253        NW                  NaN            prairie
#            SW                  NaN            prairie
# 306        NE                  NaN            prairie
#            SE                  NaN            prairie
# 317        NE                  NaN            wetland
#            NW                  NaN            wetland
#            SE                  NaN              water
#            SW                  NaN            wetland
# 338        SE                  NaN            prairie
#            SW                  NaN            prairie
# 381        NE                  NaN            prairie
#            SE                  NaN            prairie
#            SW                  NaN            prairie
# ...                            ...                ...
# 2749       SE                  NaN     forest-conifer
#            NE                  NaN     forest-conifer
#            NW                  NaN     forest-conifer
# 2781       SE                  NaN          shrubland
#            NW                  NaN     forest-conifer
# 2834       SW                  NaN   forest-deciduous
#            SE                  NaN        agriculture
#            NE                  NaN          shrubland
# 2877       NW                  NaN            prairie
#            SW                  NaN            prairie
#            NE                  NaN            prairie
# 2941       NW                  NaN   forest-deciduous
#            SW                  NaN     forest-conifer
#            NE                  NaN     forest-conifer
#            SE                  NaN     forest-conifer
# 3005       SW                  NaN     forest-conifer
#            SE                  NaN     forest-conifer
#            NE                  NaN        agriculture
#            NW                  NaN     forest-conifer
# 3053       SW                  NaN            prairie
#            NE                  NaN            prairie
#            SE                  NaN          shrubland
# 3069       NE                  NaN            prairie
#            SE                  NaN          shrubland
#            NW                  NaN          shrubland
#            SW                  NaN          shrubland
# 3197       SE                  NaN            prairie
#            NE                  NaN            prairie
# 3229       NW                  NaN          shrubland
#            SW                  NaN            prairie
#
#                   Audio Recording Name (*.wav *.zc) Software Type  \
# GridCellID SiteID
# 2          NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 61         NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 82         NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 157        NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 221        E                                     FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            NE2                                   FS   Sonobat 4.x
# 253        NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 306        NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 317        NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 338        SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 381        NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# ...                                             ...           ...
# 2749       SE                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
# 2781       SE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
# 2834       SW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
# 2877       NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
# 2941       NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 3005       SW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
# 3053       SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 3069       NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 3197       SE                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
# 3229       NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#
#                      elevation       tpi         tri
# GridCellID SiteID
# 2          NW      1449.907837  0.604791  120.189430
#            SW      1476.915405  0.269148   36.048580
#            NE      1546.029663  0.549186  117.781578
#            SE      1461.760132  0.630997  126.166557
# 61         NE      1486.125610  0.413905   58.715416
#            NW      1560.533447  0.536514   41.809090
#            SE      1484.768066  0.606869   38.245914
#            SW      1585.543579  0.586491   39.818336
# 82         NE         0.000000       NaN    0.000000
#            SE         0.000000       NaN    0.000000
# 157        NE      2205.994141  0.267560   88.625618
#            NW      2305.959229  0.605576  224.864410
#            SE      2366.882568  0.564641   69.483810
#            SW      2206.135010  0.327131   82.975899
# 221        E       1935.287231  0.452977  122.345818
#            NE      1968.767090  0.525648  149.279099
#            NE2     1916.036987  0.302777   84.424522
# 253        NW      1441.402710  0.510486  140.564041
#            SW      1368.595947  0.568465   52.051659
# 306        NE      1134.659180  0.423746   55.392914
#            SE      1093.785278  0.464407   30.728651
# 317        NE      1804.991455  0.255224   46.135670
#            NW      1943.023926  0.519142   77.772102
#            SE      1823.642334  0.513664   42.705387
#            SW      1826.976318  0.634696  114.077827
# 338        SE      1325.637939  0.515180   30.892960
#            SW      1357.595947  0.429223   37.421585
# 381        NE      1830.031372  0.645022   73.827499
#            SE      1886.032593  0.410386   60.174744
#            SW      1915.449585  0.694959   41.976185
# ...                        ...       ...         ...
# 2749       SE      2256.038818  0.559596  127.794754
#            NE      2322.395996  0.215554   78.898666
#            NW      2473.206787  0.535908  189.687897
# 2781       SE      2726.820312  0.594860    0.000000
#            NW      2823.645752  0.414987  138.517151
# 2834       SW      1277.739624  0.520547   65.241859
#            SE      1267.337280  0.674563   72.243515
#            NE      1275.358887  0.526254   98.138931
# 2877       NW      2413.615723  0.386346  230.761780
#            SW      2389.250488  0.485402   65.264847
#            NE      2350.428955  0.508444   44.536503
# 2941       NW      2630.622559  0.520499  163.497711
#            SW      2582.191162  0.349544   95.338867
#            NE      2652.547852  0.460764   90.975273
#            SE      2691.181152  0.407501  151.779449
# 3005       SW      1507.671265  0.488391  165.484131
#            SE      1476.135864  0.529077   76.072334
#            NE      1470.204346  0.605895   34.296501
#            NW      1487.801392  0.387862   80.145180
# 3053       SW      2370.428711  0.270455   32.526913
#            NE      2417.493408  0.478185   56.497787
#            SE      2468.597900  0.424223  148.345886
# 3069       NE      1770.127808  0.586032   54.532101
#            SE      1817.973267  0.335074   63.241600
#            NW      1765.691040  0.319280  127.520584
#            SW      2043.177490  0.520384  117.745491
# 3197       SE      1297.792114  0.520358   68.921150
#            NE      1289.910278  0.437814   23.674881
# 3229       NW      1672.333374  0.426869  112.478889
#            SW      1705.424683  0.437200   98.791451
#
# [148 rows x 19 columns]

# %% [markdown]
# #### Interestingly not a strong correlation between tri and tpi

# %%
import seaborn as sns
sns.set(style="darkgrid")


g = sns.jointplot("tpi", "tri", data=table4, kind="reg",
                  xlim=(0, table4.tpi.max()), ylim=(0, table4.tri.max()), color="m", height=7);
# Out:
# C:\Anaconda3\envs\pyviz\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Functions for adding NLCD landcover values

# %%
# this is a local copy of the 2011 nlcd layer available here: https://www.mrlc.gov/nlcd2011.php
nlcd_fname = r"Y:\Veg_LandCover\NLCD\nlcd11\nlcd_2011_landcover.tif"
nlcd = rasterio.open(nlcd_fname)

# %%
nlcd.crs.to_dict()
# Out:
# {'proj': 'aea',
#  'lat_1': 29.5,
#  'lat_2': 45.5,
#  'lat_0': 23,
#  'lon_0': -96,
#  'x_0': 0,
#  'y_0': 0,
#  'datum': 'NAD83',
#  'units': 'm',
#  'no_defs': True}

# %%
inProj = Proj(init='epsg:4326')
outProj = Proj(nlcd.crs.to_dict())

def wgs84_to_aes(lat, long):    
    x2,y2 = transform(inProj,outProj, long, lat)
    return (x2,y2)


wgs84_to_aes(39.290652, -114.821023)
# Out:
# (-1597933.670830356, 1966238.2312705414)

# %%
def get_nlcd(row):
    x, y = wgs84_to_aes(row['Lat'], row['Long'])
    nlcd_value = next(nlcd.sample([(x, y)]))[0]
    return nlcd_value

get_nlcd(table4.iloc[0])
# Out:
# 52

# %%
table4['nlcd'] = table4.apply(get_nlcd, axis=1)

# %%
table4.head(10)
# Out:
#                    GridCellID SiteID        Lat        Long  \
# GridCellID SiteID
# 2          NW               2     NW  39.290652 -108.821023
#            SW               2     SW  39.279238 -108.775622
#            NE               2     NE  39.332177 -108.748456
#            SE               2     SE  39.271585 -108.728060
# 61         NE              61     NE  38.052719 -104.448246
#            NW              61     NW  38.061467 -104.512655
#            SE              61     SE  38.014977 -104.460525
#            SW              61     SW  38.008945 -104.524736
# 82         NE              82     NE  40.620777 -102.642855
#            SE              82     SE  40.533334 -102.633351
#
#                                        Detector                 Microphone  \
# GridCellID SiteID
# 2          NW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            NE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
# 61         NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            NW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#            SW      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
# 82         NE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#            SE      WILDLIFE ACOUSTICS SM4Bat-FS  Wildlife Acoustics SMM-U1
#
#                    Microphone Orientation  Microphone Height (meters)  \
# GridCellID SiteID
# 2          NW                         NaN                         2.0
#            SW                         NaN                         2.0
#            NE                         NaN                         2.0
#            SE                         NaN                         2.0
# 61         NE                         NaN                         3.0
#            NW                         NaN                         3.0
#            SE                         NaN                         3.0
#            SW                         NaN                         3.0
# 82         NE                         NaN                         2.4
#            SE                         NaN                         2.4
#
#                    Distance to Nearest Clutter (meters) Clutter Type  \
# GridCellID SiteID
# 2          NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 61         NE                                       NaN   vegetation
#            NW                                       NaN   vegetation
#            SE                                       NaN   vegetation
#            SW                                       NaN   vegetation
# 82         NE                                       NaN        water
#            SE                                       NaN   vegetation
#
#                    Distance to Nearest Water (meters)  Water Type  \
# GridCellID SiteID
# 2          NW                                     NaN         NaN
#            SW                                     NaN         NaN
#            NE                                     NaN         NaN
#            SE                                     NaN         NaN
# 61         NE                                     NaN         NaN
#            NW                                     NaN         NaN
#            SE                                     NaN         NaN
#            SW                                     NaN         NaN
# 82         NE                                     NaN         NaN
#            SE                                     NaN         NaN
#
#                    Percent Clutter Broad Habitat Type  \
# GridCellID SiteID
# 2          NW                  NaN          shrubland
#            SW                  NaN          shrubland
#            NE                  NaN          shrubland
#            SE                  NaN          shrubland
# 61         NE                  NaN            prairie
#            NW                  NaN            prairie
#            SE                  NaN            prairie
#            SW                  NaN            prairie
# 82         NE                  NaN        agriculture
#            SE                  NaN        agriculture
#
#                   Audio Recording Name (*.wav *.zc) Software Type  \
# GridCellID SiteID
# 2          NW                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
#            NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
# 61         NE                                    FS   Sonobat 4.x
#            NW                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#            SW                                    FS   Sonobat 4.x
# 82         NE                                    FS   Sonobat 4.x
#            SE                                    FS   Sonobat 4.x
#
#                      elevation       tpi         tri  nlcd
# GridCellID SiteID
# 2          NW      1449.907837  0.604791  120.189430    52
#            SW      1476.915405  0.269148   36.048580    52
#            NE      1546.029663  0.549186  117.781578    52
#            SE      1461.760132  0.630997  126.166557    52
# 61         NE      1486.125610  0.413905   58.715416    71
#            NW      1560.533447  0.536514   41.809090    71
#            SE      1484.768066  0.606869   38.245914    71
#            SW      1585.543579  0.586491   39.818336    71
# 82         NE         0.000000       NaN    0.000000    71
#            SE         0.000000       NaN    0.000000    82

# %%
import geopandas as gpd

fname = r"Y:\Veg_LandCover\NLCD\nlcd11\nlcd_2011_landcover.tif.vat.dbf"

Table = gpd.read_file(fname)

import pandas as pd
nlcd_vat = pd.DataFrame(Table)
nlcd_vat = nlcd_vat[nlcd_vat.Land_Cover.notna()]
nlcd_vat.head()
# Out:
#     Value         Count       Red     Green      Blue  \
# 0       0  7.854241e+09  0.000000  0.000000  0.000000
# 11     11  4.690158e+08  0.278431  0.419608  0.627451
# 12     12  1.599206e+06  0.819608  0.866667  0.976471
# 21     21  2.924950e+08  0.866667  0.788235  0.788235
# 22     22  1.307912e+08  0.847059  0.576471  0.509804
#
#                   Land_Cover  Opacity geometry
# 0               Unclassified      1.0     None
# 11                Open Water      1.0     None
# 12        Perennial Snow/Ice      1.0     None
# 21     Developed, Open Space      1.0     None
# 22  Developed, Low Intensity      1.0     None

# %%
pd.merge(table4, nlcd_vat, left_on='nlcd', right_on='Value', how='left').set_index(['GridCellID', 'SiteID'], drop=False)['Land_Cover']
# Out:
# GridCellID  SiteID
# 2           NW                     Shrub/Scrub
#             SW                     Shrub/Scrub
#             NE                     Shrub/Scrub
#             SE                     Shrub/Scrub
# 61          NE                     Herbaceuous
#             NW                     Herbaceuous
#             SE                     Herbaceuous
#             SW                     Herbaceuous
# 82          NE                     Herbaceuous
#             SE                Cultivated Crops
# 157         NE                Evergreen Forest
#             NW                Evergreen Forest
#             SE                Evergreen Forest
#             SW                Deciduous Forest
# 221         E                      Shrub/Scrub
#             NE                     Shrub/Scrub
#             NE2                    Shrub/Scrub
# 253         NW                     Herbaceuous
#             SW                     Herbaceuous
# 306         NE                     Herbaceuous
#             SE        Developed, Low Intensity
# 317         NE                  Woody Wetlands
#             NW                     Shrub/Scrub
#             SE           Developed, Open Space
#             SW                     Herbaceuous
# 338         SE                     Herbaceuous
#             SW                Cultivated Crops
# 381         NE                     Herbaceuous
#             SE                     Herbaceuous
#             SW                     Herbaceuous
#                                 ...
# 2749        SE                     Herbaceuous
#             NE                Evergreen Forest
#             NW                     Shrub/Scrub
# 2781        SE                     Shrub/Scrub
#             NW                     Herbaceuous
# 2834        SW                  Woody Wetlands
#             SE                Cultivated Crops
#             NE                     Herbaceuous
# 2877        NW                     Shrub/Scrub
#             SW                     Shrub/Scrub
#             NE           Developed, Open Space
# 2941        NW                     Shrub/Scrub
#             SW                Evergreen Forest
#             NE                Deciduous Forest
#             SE                     Herbaceuous
# 3005        SW                     Shrub/Scrub
#             SE                Cultivated Crops
#             NE                Cultivated Crops
#             NW                     Hay/Pasture
# 3053        SW                     Shrub/Scrub
#             NE                     Shrub/Scrub
#             SE                     Shrub/Scrub
# 3069        NE                     Shrub/Scrub
#             SE                     Shrub/Scrub
#             NW                     Shrub/Scrub
#             SW                Evergreen Forest
# 3197        SE                     Herbaceuous
#             NE                     Herbaceuous
# 3229        NW                     Shrub/Scrub
#             SW                     Shrub/Scrub
# Name: Land_Cover, Length: 148, dtype: object

# %%
table4['nlcd_label'] = pd.merge(table4, nlcd_vat, left_on='nlcd', right_on='Value', how='left').set_index(['GridCellID', 'SiteID'], drop=False)['Land_Cover']
table4.head()
# Out:
#                    GridCellID SiteID        Lat        Long  \
# GridCellID SiteID
# 2          NW               2     NW  39.290652 -108.821023
#            SW               2     SW  39.279238 -108.775622
#            NE               2     NE  39.332177 -108.748456
#            SE               2     SE  39.271585 -108.728060
# 61         NE              61     NE  38.052719 -104.448246
#
#                                        Detector                 Microphone  \
# GridCellID SiteID
# 2          NW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SW        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            NE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
#            SE        WILDLIFE ACOUSTICS SM2Bat+  Wildlife Acoustics SMX-US
# 61         NE      WILDLIFE ACOUSTICS SM2Bat192  Wildlife Acoustics SMX-US
#
#                    Microphone Orientation  Microphone Height (meters)  \
# GridCellID SiteID
# 2          NW                         NaN                         2.0
#            SW                         NaN                         2.0
#            NE                         NaN                         2.0
#            SE                         NaN                         2.0
# 61         NE                         NaN                         3.0
#
#                    Distance to Nearest Clutter (meters) Clutter Type  \
# GridCellID SiteID
# 2          NW                                       NaN   vegetation
#            SW                                       NaN   vegetation
#            NE                                       NaN   vegetation
#            SE                                       NaN   vegetation
# 61         NE                                       NaN   vegetation
#
#                       ...       Water Type  Percent Clutter  \
# GridCellID SiteID     ...
# 2          NW         ...              NaN              NaN
#            SW         ...              NaN              NaN
#            NE         ...              NaN              NaN
#            SE         ...              NaN              NaN
# 61         NE         ...              NaN              NaN
#
#                    Broad Habitat Type Audio Recording Name (*.wav *.zc)  \
# GridCellID SiteID
# 2          NW               shrubland                                FS
#            SW               shrubland                                FS
#            NE               shrubland                                FS
#            SE               shrubland                                FS
# 61         NE                 prairie                                FS
#
#                   Software Type    elevation       tpi         tri  nlcd  \
# GridCellID SiteID
# 2          NW       Sonobat 4.x  1449.907837  0.604791  120.189430    52
#            SW       Sonobat 4.x  1476.915405  0.269148   36.048580    52
#            NE       Sonobat 4.x  1546.029663  0.549186  117.781578    52
#            SE       Sonobat 4.x  1461.760132  0.630997  126.166557    52
# 61         NE       Sonobat 4.x  1486.125610  0.413905   58.715416    71
#
#                     nlcd_label
# GridCellID SiteID
# 2          NW      Shrub/Scrub
#            SW      Shrub/Scrub
#            NE      Shrub/Scrub
#            SE      Shrub/Scrub
# 61         NE      Herbaceuous
#
# [5 rows x 21 columns]

# %%
table4.to_csv(out_dir.joinpath("SiteCovariates.csv"))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-21-a033b041d514> in <module>
# ----> 1 table4.to_csv(out_dir.joinpath("SiteCovariates.csv"))
#
# C:\Anaconda3\envs\pyviz\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# C:\Anaconda3\envs\pyviz\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# C:\Anaconda3\envs\pyviz\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'Z:\\TSH\\DD274_NABat\\CNHP_data_processing\\Derived\\2017_output\\SiteCovariates.csv'

# %% [markdown]
# ## Visualization of the correlation between these two sources of landcover

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 16.0

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 20]

i = table4.nlcd.sort_values().unique()
mosaic(table4, ['Broad Habitat Type', 'nlcd_label'], horizontal=True);
